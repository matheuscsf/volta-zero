# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos_mat'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos_por'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_geo'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_ing'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos_his'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos_fis'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos_qui'])

# %%
# 2) Seu código aqui
df_total_acertos = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1)
df_total_acertos['Total_acertos'] = df_total_acertos.sum(axis=1)
df_total_acertos
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 0                6               7               7               3
# 1               19              10               0               0
# 2               14              16               0               5
# 3               10               7               3               4
# 4                7               2               2               7
# ..             ...             ...             ...             ...
# 95               6               4               7               1
# 96               8               1               4               6
# 97              23               5               0               2
# 98               0              10               3               1
# 99              11              15               0               1
#
#     Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui  Total_acertos
# 0                1               8               3             35
# ...

# %%
# 1) Seu código aqui
total_questoes = 24 + 18 + 8 + 8 + 8 + 12 + 12

df_total_acertos['Percentual_acertos'] = (df_total_acertos['Total_acertos'] / total_questoes) * 100
df_total_acertos
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 0                6               7               7               3
# 1               19              10               0               0
# 2               14              16               0               5
# 3               10               7               3               4
# 4                7               2               2               7
# ..             ...             ...             ...             ...
# 95               6               4               7               1
# 96               8               1               4               6
# 97              23               5               0               2
# 98               0              10               3               1
# 99              11              15               0               1
#
#     Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui  Total_acertos  \
# 0                1               8               3             35
# ...

# %%
# 4) Seu código aqui (forma alternativa)
qtd_alunos_acima_45 = (df_total_acertos['Percentual_acertos'] > 45).sum()
qtd_alunos_acima_45
# Out:
# 47

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
#1 seu código aqui

cond_desqualificados = (df_total_acertos['Qt_acertos_mat'] == 0) | \
                       (df_total_acertos['Qt_acertos_fis'] == 0) | \
                       (df_total_acertos['Qt_acertos_qui'] == 0)

df_desqualificados = df_total_acertos[cond_desqualificados]
df_desqualificados
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 3               10               7               3               4
# 6                6               0               7               7
# 10              10               8               3               2
# 12              20               8               3               7
# 14               7              11               1               7
# 20              23              11               6               5
# 25               0               4               7               4
# 26              11              14               6               2
# 27              21              13               1               5
# 33              14               8               0               5
# 35              11              14               6               3
# 49               8               1               1               0
# 56               7               6               7               5
# ...

# %%
#2 seu código aqui

df_desqualificado['Qt_acertos'].shape
# Out:
# (23,)

# %%
#3 seu código aqui (para alunos reprovados)
media_hist_geo_desqualificados = df_desqualificados[['Qt_acertos_his', 'Qt_acertos_geo']].mean()
media_hist_geo_desqualificados
# Out:
# Qt_acertos_his    3.434783
# Qt_acertos_geo    3.217391
# dtype: float64

# %%
#3 seu código aqui (para total de alunos)

df_media_his = np.mean(df_his)
df_media_his

df_media_geo = np.mean(df_geo)
df_media_geo

print(f'A média para história é de: {df_media_his} e para geografia é de: {df_media_geo}')
# Out:
# A média para história é de: 3.6 e para geografia é de: 3.36

# %%
cond_aprovados = ~cond_desqualificados & (df_total_acertos['Percentual_acertos'] > 45)
df_aprovados_2fase = df_total_acertos[cond_aprovados]
df_aprovados_2fase
# Out:
#     Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# 1               19              10               0               0
# 2               14              16               0               5
# 5               20               2               5               3
# 7               18               4               4               7
# 8               22               9               2               7
# 11              23               6               2               0
# 17              21              15               2               2
# 18              20               4               3               5
# 24              20               2               7               5
# 29              16               0               0               2
# 31              15              13               3               1
# 34              18              14               1               0
# 36              22               9               6               6
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00004-530a8625-42c5-45cf-8672-45593d92e157.c000.csv'

# %%
# 1)
df = pd.read_csv(arquivo, sep=';')
df.head()
# Out:
#                                  document_id  \
# 0  a793dca2-239c-43b8-9102-4efbd32dfb56-i0b0
# 1  c6214907-d42d-48cd-9fd5-869dc0017aeb-i0b0
# 2  d56b4fed-37f9-4859-b2cd-774cfb17a32f-i0b0
# 3  c62f1932-a49e-47a2-8683-c5400aed835e-i0b0
# 4  5c6a4571-59b9-4aca-b0db-66f06b788905-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  6a30cfce082fc44562f9ee8af3dbf57c2f8c5136f6e916...              20
# 1  9de7536839320c318e0c384f69bd945d1ffabe29d19397...              97
# 2  16167b511949fa0737feb797acb66b756fced4cc0dcfe6...              12
# 3  19f8dace7c5632b11aed7f4431f52134e688dfe7ae9e2b...              56
# 4  4e70fefd4d3eb39084fcb7b438638b379a4f7b5a1b5f01...              46
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2001-07-06                          F                        3
# 1              1923-03-27                          F                       99
# ...

# %%
df.shape[0]
# Out:
# 383098

# %%
# 2)
df['paciente_id'].nunique()
# Out:
# 313498

# %%
# 3)
primeira_dose = df['vacina_descricao_dose'].unique()[1]
primeira_dose
# Out:
# '1ª Dose'

# %%
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 142053

# %%
# 4)
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 66486

# %%
# 5)

df['estabelecimento_razaoSocial'].nunique()
# Out:
# 57

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
df_menor = df[df["paciente_idade"]<18].copy()
df_menor.head(5)
# Out:
#                                   document_id  \
# 2   d56b4fed-37f9-4859-b2cd-774cfb17a32f-i0b0
# 6   92d44112-2e58-42a2-8e2f-5a17f1ff9cba-i0b0
# 18  223d25b7-7c79-481b-badd-08c91c4a2e4a-i0b0
# 21  c7e8ce1c-c6d1-4928-aa28-7f72379679c8-i0b0
# 24  cd4a896a-f691-4c8a-a646-ec47bc50fc84-i0b0
#
#                                           paciente_id  paciente_idade  \
# 2   16167b511949fa0737feb797acb66b756fced4cc0dcfe6...              12
# 6   d4fe5d63e27e1d7ee6cfc67fa6e64a672d68854f7f5c36...              16
# 18  50db7e4337fb4e6aabdb977e3a266fd506156e9471bd4a...              12
# 21  7a2142b11265310176ac425b9cd563b316ea07f47fe5cc...               3
# 24  6eba5ea59b784862dcdb36657a7b2c24d400fe747b4bc0...              14
#
#    paciente_dataNascimento paciente_enumSexoBiologico  \
# 2               2010-03-15                          M
# 6               2005-06-28                          F
# 18              2010-04-17                          M
# ...

# %%
# 2) 
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                       45966
# Povos Indígenas                                     4328
# Outros                                              3735
# Povos e Comunidades Tradicionais                     875
# Trabalhadores de Saúde                               235
# População Privada de Liberdade                        64
# Comorbidades                                          47
# Gestantes                                             44
# Pessoas com Deficiência                                5
# Pessoas Institucionalizadas                            3
# Trabalhadores Industriais                              2
# Trabalhadores da Educação                              2
# Puérperas                                              1
# Funcionário do Sistema de Privação de Liberdade        1
# Name: count, dtype: int64

# %%
# 4)
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

# %%
# 5)
df_menor_lista = df_menor.loc[:,lista_variaveis]
df_menor_lista
# Out:
#         estabelecimento_valor         estabelecimento_razaoSocial  \
# 2                      924490       PREFEITURA MUNICIPAL DE FEIJO
# 6                     6917291  PREFEITURA MUNICIPAL DE RIO BRANCO
# 18                    2000040       PREFEITURA MUNICIPAL DE FEIJO
# 21                    6917291  PREFEITURA MUNICIPAL DE RIO BRANCO
# 24                    6917291  PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                       ...                                 ...
# 383084                6917291  PREFEITURA MUNICIPAL DE RIO BRANCO
# 383086                2000067       PREFEITURA MUNICIPAL DE FEIJO
# 383088                6917291  PREFEITURA MUNICIPAL DE RIO BRANCO
# 383094                6917291  PREFEITURA MUNICIPAL DE RIO BRANCO
# 383097                3810771    PREFEITURA MUNICIPAL DE TARAUACA
#
#                                  estalecimento_noFantasia  \
# 2       UNIDADE MOVEL DE SAUDE FLUVIAL PEDRO RODRIGUES...
# ...

# %%
df_menor_lista = df_menor_lista.drop_duplicates()
df_menor_lista
# Out:
#         estabelecimento_valor                  estabelecimento_razaoSocial  \
# 2                      924490                PREFEITURA MUNICIPAL DE FEIJO
# 6                     6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 18                    2000040                PREFEITURA MUNICIPAL DE FEIJO
# 46                    5354072               PREFEITURA MUNICIPAL DE JORDAO
# 48                    2001217               PREFEITURA MUNICIPAL DE XAPURI
# ...                       ...                                          ...
# 279452                2001462            PREFEITURA MUNICIPAL DE BRASILEIA
# 291561                6596657  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
# 296128                 197599           CENTRAL MUNICIPAL DE REDE DE FRIOS
# 318469                2000679     PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# 343279                9296042     PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
#
#                                  estalecimento_noFantasia  \
# ...

# %%
df_menor_lista.shape
# Out:
# (193, 6)
